# %%
import pandas as pd
import numpy as np

# %%
import  numpy as np
arr=np.array([1,3,4,5,6])
print(arr)

print(arr.shape)
print(arr.size)
# Out:
# [1 3 4 5 6]
# (5,)
# 5

# %%
arr1=np.array([(1,2,3,4,5,6),(70,80,90,80,90,60)])
arr1
# Out:
# array([[ 1,  2,  3,  4,  5,  6],
#        [70, 80, 90, 80, 90, 60]])

# %%
arr1.ndim
# Out:
# 2

# %%
arr1.itemsize
# Out:
# 4

# %%
arr1.reshape(6,2)
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [ 5,  6],
#        [70, 80],
#        [90, 80],
#        [90, 60]])

# %%
arr1[0:,2]
print(arr1)
arr1[0:,1]
# Out:
# [[ 1  2  3  4  5  6]
#  [70 80 90 80 90 60]]
# array([ 2, 80])

# %%
arr2=np.linspace(1,3,5)
arr2
# Out:
# array([1. , 1.5, 2. , 2.5, 3. ])

# %%
print(arr1.max())
print(arr1.min())
arr1.sum()
# Out:
# 90
# 1
# 491

# %%
arr1
# Out:
# array([[ 1,  2,  3,  4,  5,  6],
#        [70, 80, 90, 80, 90, 60]])

# %%
print(arr1.sum(axis=1))
# Out:
# [ 21 470]

# %%
np.sqrt(arr1)
# Out:
# array([[1.        , 1.41421356, 1.73205081, 2.        , 2.23606798,
#         2.44948974],
#        [8.36660027, 8.94427191, 9.48683298, 8.94427191, 9.48683298,
#         7.74596669]])

# %%
import matplotlib.pyplot as plt
import numpy as  np
x= np.arange(0,3*np.pi,0.1)
y=np.sin(x)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as  np
x= np.arange(0,3*np.pi,0.1)
y=np.tan(x)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
xyz_web={"Day":[1,2,3,4,5,6],"visitors":[1000, 700,6000,1000,400,350],
         "Bounce_Rate":[20,20, 23,15,10,34]}
df=pd.DataFrame(xyz_web)
df
# Out:
#    Day  visitors  Bounce_Rate
# 0    1      1000           20
# 1    2       700           20
# 2    3      6000           23
# 3    4      1000           15
# 4    5       400           10
# 5    6       350           34

# %%
df.head(2)
# Out:
#    Day  visitors  Bounce_Rate
# 0    1      1000           20
# 1    2       700           20

# %%
df
# Out:
#    Day  visitors  Bounce_Rate
# 0    1      1000           20
# 1    2       700           20
# 2    3      6000           23
# 3    4      1000           15
# 4    5       400           10
# 5    6       350           34

# %%
df.tail(2)
# Out:
#    Day  visitors  Bounce_Rate
# 4    5       400           10
# 5    6       350           34

# %%
#merging

import pandas as pd

df1=pd.DataFrame({ "HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]},
                index=[2001, 2002,2003,2004])
df2=pd.DataFrame({"HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]},
                index=[2005, 2006,2007,2008])
merged=pd.merge(df1,df2)
merged
# Out:
#    HPI  Int_Rate  IND_GDP
# 0   80         2       50
# 1   90         1       45
# 2   70         2       45
# 3   60         3       67

# %%
#merging

import pandas as pd

df1=pd.DataFrame({ "HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]},
                index=[2001, 2002,2003,2004])
df2=pd.DataFrame({"HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]},
                index=[2005, 2006,2007,2008])
merged=pd.merge(df1,df2,on="HPI")
print(merged)
# Out:
#    HPI  Int_Rate_x  IND_GDP_x  Int_Rate_y  IND_GDP_y
# 0   80           2         50           2         50
# 1   90           1         45           1         45
# 2   70           2         45           2         45
# 3   60           3         67           3         67

# %%
df1 = pd.DataFrame({"Int_Rate":[2,1,2,3], "IND_GDP":[50,45,45,67]}, index=[2001, 2002,2003,2004])
 
df2 = pd.DataFrame({"Low_Tier_HPI":[50,45,67,34],"Unemployment":[1,3,5,6]}, index=[2001, 2003,2004,2004])
 
print(df1)
print(df2)
df1.join(df2)
# Out:
#       Int_Rate  IND_GDP
# 2001         2       50
# 2002         1       45
# 2003         2       45
# 2004         3       67
#       Low_Tier_HPI  Unemployment
# 2001            50             1
# 2003            45             3
# 2004            67             5
# 2004            34             6
#       Int_Rate  IND_GDP  Low_Tier_HPI  Unemployment
# 2001         2       50          50.0           1.0
# 2002         1       45           NaN           NaN
# 2003         2       45          45.0           3.0
# 2004         3       67          67.0           5.0
# 2004         3       67          34.0           6.0

# %%
df1 = pd.DataFrame({"HPI":[80,90,70,60],"Int_Rate":[2,1,2,3], "IND_GDP":[50,45,45,67]}, index=[2001, 2002,2003,2004])
 
df2 = pd.DataFrame({"HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]}, index=[2005, 2006,2007,2008])
 
print(df1)
print(df2)
concat=pd.concat([df1,df2],axis=1)
concat
# Out:
#       HPI  Int_Rate  IND_GDP
# 2001   80         2       50
# 2002   90         1       45
# 2003   70         2       45
# 2004   60         3       67
#       HPI  Int_Rate  IND_GDP
# 2005   80         2       50
# 2006   90         1       45
# 2007   70         2       45
# 2008   60         3       67
#        HPI  Int_Rate  IND_GDP   HPI  Int_Rate  IND_GDP
# 2001  80.0       2.0     50.0   NaN       NaN      NaN
# 2002  90.0       1.0     45.0   NaN       NaN      NaN
# 2003  70.0       2.0     45.0   NaN       NaN      NaN
# 2004  60.0       3.0     67.0   NaN       NaN      NaN
# 2005   NaN       NaN      NaN  80.0       2.0     50.0
# 2006   NaN       NaN      NaN  90.0       1.0     45.0
# 2007   NaN       NaN      NaN  70.0       2.0     45.0
# 2008   NaN       NaN      NaN  60.0       3.0     67.0

# %%
import pandas as pd
df=pd.DataFrame({"Day":[1,2,3,4], "Visitors":[200, 100,230,300], "Bounce_Rate":[20,45,60,10]},)
df.set_index("Day",inplace=True)
df
# Out:
#      Visitors  Bounce_Rate
# Day
# 1         200           20
# 2         100           45
# 3         230           60
# 4         300           10

# %%
import pandas as pd
df=pd.DataFrame({"Day":[1,2,3,4], "Visitors":[200, 100,230,300], "Bounce_Rate":[20,45,60,10]},)
df = df.rename(columns={"Visitors":"Users1"})
df
# Out:
#    Day  Users1  Bounce_Rate
# 0    1     200           20
# 1    2     100           45
# 2    3     230           60
# 3    4     300           10

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"C:\Users\Gopal Chavan\Desktop\Datasets\titanic\train.csv")
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df=pd.DataFrame()

# %%
df["Name"]=["Gpo","sop","Rom"]
df["Age"]=[36,56,78]
df["Country"]=["sdf","asf","asf"]

# %%
df
# Out:
#   Name  Age Country
# 0  Gpo   36     sdf
# 1  sop   56     asf
# 2  Rom   78     asf

# %%
new_row=pd.Series(["Angilo",23,"sri"],index=["Name","Age","Country"])
new_row
# Out:
# Name       Angilo
# Age            23
# Country       sri
# dtype: object

# %%
df.append(new_row,ignore_index=True, )
# Out:
#    Day  Users1  Bounce_Rate   Age Country    Name
# 0  1.0   200.0         20.0   NaN     NaN     NaN
# 1  2.0   100.0         45.0   NaN     NaN     NaN
# 2  3.0   230.0         60.0   NaN     NaN     NaN
# 3  4.0   300.0         10.0   NaN     NaN     NaN
# 4  NaN     NaN          NaN  23.0     sri  Angilo

# %%
df.head
# Out:
# <bound method NDFrame.head of    Day  Users1  Bounce_Rate
# 0    1     200           20
# 1    2     100           45
# 2    3     230           60
# 3    4     300           10>

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset.iloc[0][4]


print(dataset.iloc[4:5])
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch  Ticket  Fare Cabin Embarked
# 4      0  373450  8.05   NaN        S

# %%
dataset.iloc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %%
df=df.set_index(df["Name"])
dataset
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-75a95f3f218a> in <module>
# ----> 1 df=df.set_index(df["Name"])
# ...

# %%
dataset.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset[dataset["Pclass"]==1].head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 6      0     17463  51.8625   E46        S

# %%
dataset[(dataset["Sex"] == "male") & (dataset["Age"]>40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 33            34         0       2
# 35            36         0       1
# 54            55         0       1
# 62            63         0       1
# 92            93         0       1
# 94            95         0       3
# 96            97         0       1
# 110          111         0       1
# 116          117         0       3
# 124          125         0       1
# 129          130         0       3
# 149          150         0       2
# 150          151         0       2
# 152          153         0       3
# 153          154         0       3
# 155          156         0       1
# 160          161         0       3
# 170          171         0       1
# 174          175         0       1
# 187          188         1       1
# 197          198         0       3
# 203          204         0       3
# 217          218         0       2
# 222          223         0       3
# ...

# %%
dataset["Sex"].replace("male","men")
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
dataset["col1"]=dataset["Sex"].replace("male","men")
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
dataset["Age"].max()
# Out:
# 80.0

# %%
dataset["Age"].min()
# Out:
# 0.42

# %%
dataset["Age"].sum()
# Out:
# 21205.17

# %%
dataset["Age"].count()
# Out:
# 714

# %%
dataset["Age"].mean()
# Out:
# 29.69911764705882

# %%
dataset["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
print(dataset["Sex"].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# col1           891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# col1           891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
dataset[dataset["Age"].isnull()].head(100)
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
dataset[dataset["Age"].notnull()].head(100)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# ...

# %%
dataset["Sex"]=dataset["Sex"].replace("female",np.nan)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            577 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# col1           891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"C:\Users\Gopal Chavan\Desktop\Datasets\titanic\train.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df1=dataset.drop("Name",axis=1)

# %%
df1.head(10)
# Out:
#       HPI  Int_Rate  IND_GDP
# 2001   80         2       50
# 2002   90         1       45
# 2003   70         2       45
# 2004   60         3       67

# %%
df1=df1.drop(["Pclass","Cabin"],axis=1)

# %%
df1.head(10)
# Out:
#       HPI  Int_Rate  IND_GDP
# 2001   80         2       50
# 2002   90         1       45
# 2003   70         2       45
# 2004   60         3       67

# %%
df1=df1.drop(df1.columns[1],axis=1)

# %%
df1.head()
# Out:
#    PassengerId     Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0            1    male  22.0      1      0         A/5 21171   7.2500        S
# 1            2  female  38.0      1      0          PC 17599  71.2833        C
# 2            3  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3            4  female  35.0      1      0            113803  53.1000        S
# 4            5    male  35.0      0      0            373450   8.0500        S

# %%
df2=df1.drop(df1.columns[[1,3]],axis=1)

# %%
df2.head()
# Out:
#    PassengerId   Age  Parch            Ticket     Fare Embarked
# 0            1  22.0      0         A/5 21171   7.2500        S
# 1            2  38.0      0          PC 17599  71.2833        C
# 2            3  26.0      0  STON/O2. 3101282   7.9250        S
# 3            4  35.0      0            113803  53.1000        S
# 4            5  35.0      0            373450   8.0500        S

# %%
df3=df2.drop(df2.index[[1,3]])

# %%
df3.head()
# Out:
#    PassengerId   Age  Parch            Ticket     Fare Embarked
# 0            1  22.0      0         A/5 21171   7.2500        S
# 2            3  26.0      0  STON/O2. 3101282   7.9250        S
# 4            5  35.0      0            373450   8.0500        S
# 5            6   NaN      0            330877   8.4583        Q
# 6            7  54.0      0             17463  51.8625        S

# %%
df3["Embarked"].unique()
# Out:
# array(['S', 'Q', 'C', nan], dtype=object)

# %%
df3=df3[df3["Embarked"] != "S"].head()

# %%
df3
# Out:
#     PassengerId   Age  Parch  Ticket     Fare Embarked
# 5             6   NaN      0  330877   8.4583        Q
# 9            10  14.0      0  237736  30.0708        C
# 16           17   2.0      1  382652  29.1250        Q
# 19           20   NaN      0    2649   7.2250        C
# 22           23  15.0      0  330923   8.0292        Q

# %%
df3["Embarked"].unique()
# Out:
# array(['Q', 'C'], dtype=object)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 5 to 22
# Data columns (total 6 columns):
# PassengerId    5 non-null int64
# Age            3 non-null float64
# Parch          5 non-null int64
# Ticket         5 non-null object
# Fare           5 non-null float64
# Embarked       5 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 280.0+ bytes

# %%
dup=df3.drop_duplicates().head()

# %%
dup
# Out:
#     PassengerId   Age  Parch  Ticket     Fare Embarked
# 5             6   NaN      0  330877   8.4583        Q
# 9            10  14.0      0  237736  30.0708        C
# 16           17   2.0      1  382652  29.1250        Q
# 19           20   NaN      0    2649   7.2250        C
# 22           23  15.0      0  330923   8.0292        Q

# %%
dup=dup.drop_duplicates(subset=["Embarked"])

# %%
dup
# Out:
#    PassengerId   Age  Parch  Ticket     Fare Embarked
# 5            6   NaN      0  330877   8.4583        Q
# 9           10  14.0      0  237736  30.0708        C

# %%
dup=df3.drop_duplicates(subset=["Embarked"],keep="last")

# %%
dup
# Out:
#     PassengerId   Age  Parch  Ticket    Fare Embarked
# 19           20   NaN      0    2649  7.2250        C
# 22           23  15.0      0  330923  8.0292        Q

# %%
df1
# Out:
#      PassengerId     Sex   Age  SibSp  Parch            Ticket      Fare  \
# 0              1    male  22.0      1      0         A/5 21171    7.2500
# 1              2  female  38.0      1      0          PC 17599   71.2833
# 2              3  female  26.0      0      0  STON/O2. 3101282    7.9250
# 3              4  female  35.0      1      0            113803   53.1000
# 4              5    male  35.0      0      0            373450    8.0500
# 5              6    male   NaN      0      0            330877    8.4583
# 6              7    male  54.0      0      0             17463   51.8625
# 7              8    male   2.0      3      1            349909   21.0750
# 8              9  female  27.0      0      2            347742   11.1333
# 9             10  female  14.0      1      0            237736   30.0708
# 10            11  female   4.0      1      1           PP 9549   16.7000
# 11            12  female  58.0      0      0            113783   26.5500
# ...

# %%
df1.groupby("Sex")

# %%
df1.groupby("Sex").mean()
# Out:
#         PassengerId        Age     SibSp     Parch       Fare
# Sex
# female   431.028662  27.915709  0.694268  0.649682  44.479818
# male     454.147314  30.726645  0.429809  0.235702  25.523893

# %%
df1.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
dataset.groupby(["Sex","Survived"])["Age"].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %%
dataset.groupby(["Sex","Survived","Pclass"])["Age"].mean()
# Out:
# Sex     Survived  Pclass
# female  0         1         25.666667
#                   2         36.000000
#                   3         23.818182
#         1         1         34.939024
#                   2         28.080882
#                   3         19.329787
# male    0         1         44.581967
#                   2         33.369048
#                   3         27.255814
#         1         1         36.248000
#                   2         16.022000
#                   3         22.274211
# Name: Age, dtype: float64

# %%
ts_index=pd.date_range("01/01/2020",periods=20000000,freq="60s")

# %%
df=pd.DataFrame(index=ts_index)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-01 00:00:00, 2020-01-01 00:01:00, 2020-01-01 00:02:00, 2020-01-01 00:03:00, 2020-01-01 00:04:00]

# %%
df["no_of_vehicle"]=np.random.randint(1,10,20000000)

# %%
df.head()
# Out:
#                      no_of_vehicle
# 2020-01-01 00:00:00              3
# 2020-01-01 00:01:00              6
# 2020-01-01 00:02:00              4
# 2020-01-01 00:03:00              7
# 2020-01-01 00:04:00              8

# %%
df.resample("W").sum().head()
# Out:
#             no_of_vehicle
# 2020-01-05          36138
# 2020-01-12          50686
# 2020-01-19          50200
# 2020-01-26          50050
# 2020-02-02          50446

# %%
df.resample("M").sum().head()
# Out:
#             no_of_vehicle
# 2020-01-31         223150
# 2020-02-29         208890
# 2020-03-31         223220
# 2020-04-30         215751
# 2020-05-31         222944

# %%
ts_value=pd.date_range("01/01/2020",periods=200000,freq="15s")

# %%
ts_value
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:00:15',
#                '2020-01-01 00:00:30', '2020-01-01 00:00:45',
#                '2020-01-01 00:01:00', '2020-01-01 00:01:15',
#                '2020-01-01 00:01:30', '2020-01-01 00:01:45',
#                '2020-01-01 00:02:00', '2020-01-01 00:02:15',
#                ...
#                '2020-02-04 17:17:30', '2020-02-04 17:17:45',
#                '2020-02-04 17:18:00', '2020-02-04 17:18:15',
#                '2020-02-04 17:18:30', '2020-02-04 17:18:45',
#                '2020-02-04 17:19:00', '2020-02-04 17:19:15',
#                '2020-02-04 17:19:30', '2020-02-04 17:19:45'],
#               dtype='datetime64[ns]', length=200000, freq='15S')

# %%
df=pd.DataFrame()

# %%
df["Datetime"]=ts_value

# %%
df.head()
# Out:
#              Datetime
# 0 2020-01-01 00:00:00
# 1 2020-01-01 00:00:15
# 2 2020-01-01 00:00:30
# 3 2020-01-01 00:00:45
# 4 2020-01-01 00:01:00

# %%
df["Year"]=df.Datetime.dt.year

# %%
df["Month"]=df.Datetime.dt.month

# %%
df["Day"]=df.Datetime.dt.day

# %%
df["Weekday_Name"]=df.Datetime.dt.weekday_name

# %%
df.head()
# Out:
#              Datetime  Year  Month  Day Weekday_Name
# 0 2020-01-01 00:00:00  2020      1    1    Wednesday
# 1 2020-01-01 00:00:15  2020      1    1    Wednesday
# 2 2020-01-01 00:00:30  2020      1    1    Wednesday
# 3 2020-01-01 00:00:45  2020      1    1    Wednesday
# 4 2020-01-01 00:01:00  2020      1    1    Wednesday

# %%
df["Hour"]=df.Datetime.dt.hour

# %%
df["Minutes"]=df.Datetime.dt.minute

# %%
df["Second"]=df.Datetime.dt.second

# %%
df["microsecond"]=df.Datetime.dt.microsecond

# %%
df.head()
# Out:
#              Datetime  Year  Month  Day Weekday_Name  Hour  Minutes  Second  \
# 0 2020-01-01 00:00:00  2020      1    1    Wednesday     0        0       0
# 1 2020-01-01 00:00:15  2020      1    1    Wednesday     0        0      15
# 2 2020-01-01 00:00:30  2020      1    1    Wednesday     0        0      30
# 3 2020-01-01 00:00:45  2020      1    1    Wednesday     0        0      45
# 4 2020-01-01 00:01:00  2020      1    1    Wednesday     0        1       0
#
#    microsecond
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df.tail()
# Out:
#                   Datetime  Year  Month  Day Weekday_Name  Hour  Minutes  \
# 199995 2020-02-04 17:18:45  2020      2    4      Tuesday    17       18
# 199996 2020-02-04 17:19:00  2020      2    4      Tuesday    17       19
# 199997 2020-02-04 17:19:15  2020      2    4      Tuesday    17       19
# 199998 2020-02-04 17:19:30  2020      2    4      Tuesday    17       19
# 199999 2020-02-04 17:19:45  2020      2    4      Tuesday    17       19
#
#         Second  microsecond
# 199995      45            0
# 199996       0            0
# 199997      15            0
# 199998      30            0
# 199999      45            0

# %%
Daf=pd.DataFrame()

# %%
Name=["Ramu","Shamu","Golu","Kavu"]
sex=["Male","male","male","Female"]
ID=[20,5,6,66]
Country=["ind","sriu","Aus","canada"]

# %%
Daf["Name"]=Name
Daf["sex"]=sex
Daf["ID"]=ID
Daf["Country"]=Country

# %%
Daf
# Out:
#     Name     sex  ID Country
# 0   Ramu    Male  20     ind
# 1  Shamu    male   5    sriu
# 2   Golu    male   6     Aus
# 3   Kavu  Female  66  canada

# %%
for name in Daf["Name"]:
    print(name.upper())
# Out:
# RAMU
# SHAMU
# GOLU
# KAVU

# %%
for name in Daf["Name"][0:2]:
    print(name.upper())
# Out:
# RAMU
# SHAMU
