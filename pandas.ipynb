# %%
import pandas as pd

data=[1,2,3,45]

Series1=pd.Series(data)
print(Series1)

# %%
from random import *

for i in range(10):
    print(randint(0,9),randint(0,9),randint(0,9),randint(0,9),randint(0,9),randint(0,9),randint(0,9), sep="")
# Out:
# 3797175
# 1228560
# 2488212
# 2142112
# 0190628
# 9111112
# 4903047
# 7374518
# 1681910
# 8540718

# %%
from math import *

print(tan(45))

# %%
from random import *

for i in range(10):
    print(chr(randint(65,65+25)),sep="")

# %%
import pandas as pd

sam_dict={" Ramu":[23,56,67,45]   ,"Samu":[45,50,34,45]  ,"Pihu": [90,45,23,45] }

df=pd.DataFrame(sam_dict)
df

# %%
import pandas as pd

Data= {"Apple": [12,15,13,18]  , "Banana": [12,67,98,56]}

purchase=pd.DataFrame(Data)
purchase
# Out:
#    Apple  Banana
# 0     12      12
# 1     15      67
# 2     13      98
# 3     18      56

# %%
import pandas as pd

purchase=pd.DataFrame(Data, index=["Gopal","Ramu","Samu","Hemu"])
purchase

# %%
import pandas as pd
print(purchase.loc["Gopal"])

print()

print(purchase.loc["Hemu"])

print()
print(purchase.loc["Samu"])

print()
print(purchase.max())

print()
print(purchase.min())

print()
print(purchase.mode())

print()
print(purchase)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Gopal'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-67eb13c6cb22> in <module>
#       1 import pandas as pd
# ----> 2 print(purchase.loc["Gopal"])
#       3
#       4 print()
#       5
#
# ...

# %%
import pandas as pd

Data={ "Age":[12,23,45,50], "Rating":[29,87,66,56]}

ppl_list=pd.DataFrame(Data)
ppl_list

# %%
ppl_list=pd.DataFrame(Data,index=["Gopu","Abhu","Sahu","Ramu"])
ppl_list
# Out:
#       Apple  Banana
# Gopu     12      12
# Abhu     15      67
# Sahu     13      98
# Ramu     18      56

# %%
ppl_list.loc["Gopu"]

# %%
ppl_list.loc["Sahu"]

# %%
import pandas as pd

S=pd.Series
print(S)
# Out:
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd
import numpy as np

Data=np.array(["A","B","C","D"])

S1=pd.Series(Data)

print(S1)
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
S2=pd.Series(Data,index=[10,20,30,40])
print(S2)

# %%
import pandas as pd
import numpy as np

Data={"Samu":23,"GOpu":56,"Sonu":34}
S3=pd.Series(Data)


next1={"same":98,"Raje":90,"Rima":45}
S4=pd.Series(next1)

print(S4)
print()
print(S3)
# Out:
# same    98
# Raje    90
# Rima    45
# dtype: int64
#
# Samu    23
# GOpu    56
# Sonu    34
# dtype: int64

# %%
import pandas as pd
import numpy as np

Data={"Samu":[23,34,25,50],"GOpu":[56,90,78,45],"Sonu":[34,90,67,54]}
S3=pd.Series(Data)
Data1=pd.DataFrame(Data,index=["Row","Rpw2","Row3","Row4"])
print(S3)
Data1
# Out:
# Samu    [23, 34, 25, 50]
# GOpu    [56, 90, 78, 45]
# Sonu    [34, 90, 67, 54]
# dtype: object
#       Samu  GOpu  Sonu
# Row     23    56    34
# Rpw2    34    90    90
# Row3    25    78    67
# Row4    50    45    54

# %%
import pandas as pd
import numpy as np
s=pd.Series([1,2,3,4,5], index=["a","b","c","d","e"])
print(s)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
import pandas as pd

df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

Data=[12,23,34,45,56]
df=pd.DataFrame(Data)
print(df)
# Out:
#     0
# 0  12
# 1  23
# 2  34
# 3  45
# 4  56

# %%
import pandas as pd

Data=[["Alex",23], ["Gopal",24], ["Sonu",89], ["Dude",56]]

df=pd.DataFrame(Data)
print(df)
# Out:
#        0   1
# 0   Alex  23
# 1  Gopal  24
# 2   Sonu  89
# 3   Dude  56

# %%
import pandas as pd

Data=[["Alex",23], ["Gopal",24], ["Sonu",89], ["Dude",56]]

df=pd.DataFrame(Data,columns=["Name","Age"])
df

# %%
import pandas as pd

Data=[["Alex",23], ["Gopal",24], ["Sonu",89], ["Dude",56]]

df=pd.DataFrame(Data,columns=["Name","Age"])
df
# Out:
#     Name  Age
# 0   Alex   23
# 1  Gopal   24
# 2   Sonu   89
# 3   Dude   56

# %%
import pandas as pd

Data=[["Alex",23], ["Gopal",24], ["Sonu",89], ["Dude",56]]

df=pd.DataFrame(Data,columns=["Name","Age"],dtype=float)
df

# %%
import pandas as pd

Data={"Name": ["Sunny","Bunny","Tinny","Raju"], "Age": [12,13,14,15]}

df=pd.DataFrame(Data)
df
# Out:
#     Name  Age
# 0  Sunny   12
# 1  Bunny   13
# 2  Tinny   14
# 3   Raju   15

# %%
import pandas as pd

Data={"Name": ["Sunny","Bunny","Tinny","Raju"], "Age": [12,13,14,15]}

df=pd.DataFrame(Data,copy=["Sunny"])
df
# Out:
#     Name  Age
# 0  Sunny   12
# 1  Bunny   13
# 2  Tinny   14
# 3   Raju   15

# %%
import pandas as pd

Data={ "Name": ["Sunny","Bunny","Tinny","Raju"], "Age": [12,13,14,15]}
df=pd.DataFrame(Data,index=["rank1","rank2","rank3","rank4"])
df
# Out:
#         Name  Age
# rank1  Sunny   12
# rank2  Bunny   13
# rank3  Tinny   14
# rank4   Raju   15

# %%
import pandas as pd

Data=[ {"A":2,"B":3}, {"A":3,"B":5,"C":5, "D":7}]
df=pd.DataFrame(Data,index=["Fisrt","Second"])
df
# Out:
#         A  B    C    D
# Fisrt   2  3  NaN  NaN
# Second  3  5  5.0  7.0

# %%
import pandas as pd

Data=[ {"A":2,"B":3}, {"A":3,"B":5,"C":5, "D":7}]
df=pd.DataFrame(Data,index=["Fisrt","Second"])
df["E"]=pd.Series([12,23,5,4],index=[4,5,6,7])
df
# Out:
#         A  B    C    D   E
# Fisrt   2  3  NaN  NaN NaN
# Second  3  5  5.0  7.0 NaN

# %%
import pandas as pd

Data={ "One": [1,2,3,4], "Two":[5,6,7,8], "Three": [9,8,7,6]}
df=pd.DataFrame(Data)
df1=df["One"]+df["Two"]
print(df1)

print()

df["Four"]=pd.Series([5,8,9,3])
print(df)

# %%
import pandas as pd
import numpy as np

data = np.random.rand(2,4,5)
p = pd.Panel(data)
p
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3325: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.panel.Panel'>
# Dimensions: 2 (items) x 4 (major_axis) x 5 (minor_axis)
# Items axis: 0 to 1
# Major_axis axis: 0 to 3
# Minor_axis axis: 0 to 4

# %%
import pandas as pd
import numpy as np

data={"item1": pd.DataFrame(np.random.rand(4,3)),  "item2": pd.DataFrame(np.random.rand(4,2))}

p=pd.Panel(data)
print(p)

# %%
import pandas as pd
p=pd.Panel()
print(p)
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 0 (items) x 0 (major_axis) x 0 (minor_axis)
# Items axis: None
# Major_axis axis: None
# Minor_axis axis: None

# %%
import pandas as pd
import numpy as np

data={"item1": pd.DataFrame(np.random.rand(4,3)),  "item2": pd.DataFrame(np.random.rand(4,2))}

p=pd.Panel(data)
print(p["item1"])

print()
print(p["item2"])

print("\n")
print(p.ndim)
# Out:
#           0         1         2
# 0  0.017240  0.129764  0.846213
# 1  0.259955  0.777570  0.248620
# 2  0.070151  0.468118  0.454749
# 3  0.410840  0.963236  0.683901
#
#           0         1   2
# 0  0.326188  0.245629 NaN
# 1  0.762140  0.428687 NaN
# 2  0.180313  0.574824 NaN
# 3  0.573752  0.903505 NaN
#
#
# 3

# %%
import pandas as pd
import numpy as np

data={"item1": pd.DataFrame(np.random.rand(4,3)),  "item2": pd.DataFrame(np.random.rand(4,2))}

p=pd.Panel(data)
print(p.major_xs(1))

print()
print(p["item2"])
# Out:
#       item1     item2
# 0  0.931140  0.243059
# 1  0.936322  0.381188
# 2  0.645956       NaN
#
#           0         1   2
# 0  0.713439  0.920259 NaN
# 1  0.243059  0.381188 NaN
# 2  0.318720  0.829288 NaN
# 3  0.105374  0.535884 NaN

# %%
import pandas as pd
import numpy as np

s=pd.Series(np.random.rand(4))
s

# %%
import pandas as pd
import numpy as np

s=pd.Series(np.random.rand(4))
print(s.axes)
print(s.size)
print("\n")

print(s.head(2))
# Out:
# [RangeIndex(start=0, stop=4, step=1)]
# 4
#
#
# 0    0.452021
# 1    0.933698
# dtype: float64

# %%
import pandas as pd
import numpy as np


data={ "Name":pd.Series(["raju","samu","gopu","topu","ritu"]) , "Age":pd.Series( [12,13,14,15,16,17]),
      "Rating": pd.Series([33,44,55,66,77,88])}
S=pd.Series(data)

print(S)
df=pd.DataFrame(data)
print(df)
# Out:
# Name      0    raju
# 1    samu
# 2    gopu
# 3    topu
# 4    r...
# Age       0    12
# 1    13
# 2    14
# 3    15
# 4    16
# 5    1...
# Rating    0    33
# 1    44
# 2    55
# 3    66
# 4    77
# 5    8...
# dtype: object
#    Name  Age  Rating
# 0  raju   12      33
# 1  samu   13      44
# 2  gopu   14      55
# 3  topu   15      66
# 4  ritu   16      77
# 5   NaN   17      88

# %%
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack']),
   'Age':pd.Series([25,26,25,23,30,29,23]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8])}



#Create a DataFrame
df = pd.DataFrame(d)
print ("Our data series is:")
print (df.T)
# Out:
# Our data series is:
#            0      1      2     3      4      5     6
# Name     Tom  James  Ricky   Vin  Steve  Smith  Jack
# Age       25     26     25    23     30     29    23
# Rating  4.23   3.24   3.98  2.56    3.2    4.6   3.8

# %%
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack']),
   'Age':pd.Series([25,26,25,23,30,29,23]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8])}



#Create a DataFrame
df = pd.DataFrame(d)
print ("Our data series is:")
print (df)
# Out:
# Our data series is:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Smith   29    4.60
# 6   Jack   23    3.80

# %%
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
print (df.sum())

print("\n")
print(df.mean())
print("\n")
print(df.median())

# %%
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)
print (df.sum(1))

print("\n")
print(df.mean())
print("\n")
print(df.median())
print(df.std())

# %%
import pandas as pd
 
zensar = pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\BSE-BOM504067.csv")
zensar['Year'] = pd.to_datetime(zensar.Date).dt.year
print(zensar[zensar['Year'] == 2019]['Close'].mean())
print("\n")
# Out:
# 229.70973684210526

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\BSE-BOM504067.csv")

print(df)

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\BSE-BOM504067.csv")

print(df.mean())
# Out:
# Open                         2.695235e+02
# High                         2.752779e+02
# Low                          2.639520e+02
# Close                        2.690109e+02
# WAP                          2.647366e+02
# No. of Shares                2.145142e+04
# No. of Trades                4.310464e+02
# Total Turnover               5.058117e+06
# Deliverable Quantity         1.088174e+04
# % Deli. Qty to Traded Qty    5.263325e+01
# Spread H-L                   1.132591e+01
# Spread C-O                  -5.125988e-01
# dtype: float64

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.csv")

print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.xlsx")

print(df.head(5))

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")

print(df.head(5))

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")

print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")
df.loc[df["Type 1"]=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")
df.loc[df["Type 1"]=="Grass"]
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1                Bulbasaur  Grass    Poison   45      49       49
# 1      2                  Ivysaur  Grass    Poison   60      62       63
# 2      3                 Venusaur  Grass    Poison   80      82       83
# 3      3    VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                   Oddish  Grass    Poison   45      50       55
# 49    44                    Gloom  Grass    Poison   60      65       70
# 50    45                Vileplume  Grass    Poison   75      80       85
# 75    69               Bellsprout  Grass    Poison   50      75       35
# 76    70               Weepinbell  Grass    Poison   65      90       50
# 77    71               Victreebel  Grass    Poison   80     105       65
# 110  102                Exeggcute  Grass   Psychic   60      40       80
# 111  103                Exeggutor  Grass   Psychic   95      95       85
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")
df.sort_values(["Type 1","HP"],ascending=[0,0])

# %%
df.head(5)

# %%
df["Total"]=df["HP"]+ df["Attack"]+ df["Defense"]+ df["Sp. Def"]+ df["Speed"]
(df.head())
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    253
# 1       80     60           1      False    325
# 2      100     80           1      False    425
# 3      120     80           1      False    503
# 4       50     65           1      False    249

# %%
df=df.drop(columns=["Total"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-8a851cdc71d3> in <module>
# ----> 1 df=df.drop(columns=["Total"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")
df["Total"]=df["HP"]+ df["Attack"]+ df["Defense"]+ df["Sp. Def"]+ df["Speed"]

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")
df["Total"]=df["HP"]+ df["Attack"]+ df["Defense"]+ df["Sp. Def"]+ df["Speed"]

df.drop(columns=["Total"])
df.head(5)

# %%
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison")]
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# ...

# %%
import pandas as pd
new_def=pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\pokemon_data.txt",delimiter="\t")
new_def=df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison") & (df["HP"] > 70) ] 

new_def.to_csv("Filterd.csv")

new_def
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 2        100     80           1      False    425
# 3        120     80           1      False    503
# 50        90     50           1      False    380
# 77        70     70           1      False    390
# 652       80     30           5      False    379

# %%
df.loc[df["Name"].str.contains("Mega")]
df.head(10)

# %%
df.loc[~df["Name"].str.contains("Mega")]

# %%
df.loc[df["Name"].str.contains("Mega")]

# %%
import pandas as pd
import numpy as np


df={"C1":pd.Series(["A","B","C"]),  
    "C2":pd.Series([5,6,7,4,5,5,6])}
print(df)
# Out:
# {'C1': 0    A
# 1    B
# 2    C
# dtype: object, 'C2': 0    5
# 1    6
# 2    7
# 3    4
# 4    5
# 5    5
# 6    6
# dtype: int64}

# %%
import pandas as pd
import  numpy as np

data=np.array(["A","B","C","D"])
print(pd.Series(5,index=["A","b"]))
print(pd.Series(data,index=[100,200,300,400]))

# %%
import pandas as pd
import  numpy as np

data=[ ["Gopal",100], ["Ram",200], ["MAngesh",300]]
pd.DataFrame(data,columns=["Name","Age"],index=[1,2,3])
# Out:
#       Name  Age
# 1    Gopal  100
# 2      Ram  200
# 3  MAngesh  300

# %%
import pandas as pd
import numpy as np

data= {"Name":["GOpal","Ram","mangesh"] , "Age": [23,45,67]}
pd.DataFrame(data,index=["Rank1","Rank1","Rank3"])
# Out:
#           Name  Age
# Rank1    GOpal   23
# Rank1      Ram   45
# Rank3  mangesh   67

# %%
import pandas as pd
import numpy as np

data =[{"A":23,"B":78,"C":34},{"A":45,"B":78,"C":34}]

pd.DataFrame(data,index=[1,2])
# Out:
#     A   B   C
# 1  23  78  34
# 2  45  78  34

# %%
import pandas as pd
import numpy as np

data= {"one":pd.Series([1,2,3],index=["A","B","C"]),"Two":pd.Series([4,5,6],index=["A","B","C"])
      }

df=pd.DataFrame(data)
df.iloc[2]
# Out:
# one    3
# Two    6
# Name: C, dtype: int64

# %%
import pandas as pd
import numpy as np

s=pd.Series(np.random.randint(10))
print(s)
# Out:
# 0    9
# dtype: int64

# %%
import  pandas as pd
import numpy as np

heights_A =pd.Series([176.2, 158.4, 167.6, 156.2, 161.4],index=(["s1", "s2", "s3", "s4","s5"]))
print(heights_A)
print(heights_A.shape)


weights_A=pd.Series([85.1, 90.2, 76.8, 80.4,78.9],index=(["s1", "s2", "s3", "s4","s5"]))
print(weights_A.shape)
# Out:
# s1    176.2
# s2    158.4
# s3    167.6
# s4    156.2
# s5    161.4
# dtype: float64
# (5,)
# (5,)

# %%
df_A=pd.DataFrame({"heights_A":[176.2, 158.4, 167.6, 156.2, 161.4],
                   "weights_A":[85.1, 90.2, 76.8, 80.4,78.9]},index=["s1", "s2", "s3", "s4","s5"])

print(df_A)
# Out:
#     heights_A  weights_A
# s1      176.2       85.1
# s2      158.4       90.2
# s3      167.6       76.8
# s4      156.2       80.4
# s5      161.4       78.9

# %%
import pandas as pd

data=[1,2,3,45]

Series1=pd.Series(data)
print(Series1)
# Out:
# 0     1
# 1     2
# 2     3
# 3    45
# dtype: int64

# %%
Series1=pd.Series(data,index=["Rank1","Rank2","Rank3","Rank4"])
print(Series1)
# Out:
# Rank1     1
# Rank2     2
# Rank3     3
# Rank4    45
# dtype: int64

# %%
import numpy as np

numpyarray=np.array([ [400000,344455],["Ramu","Gopu"]])
df=pd.DataFrame({"Name":numpyarray[1],"Salry":numpyarray[0]},index=[1,2])
print(df)
# Out:
#    Name   Salry
# 1  Ramu  400000
# 2  Gopu  344455

# %%
import pandas as pd
df1=pd.DataFrame ({ "HP1": [80,90,70,60], "int_rate": [2,1,2,3], "IND_GDP":[50,45,70,90]}, index=[ 2001,2002,2003,2004])
df2=pd.DataFrame ({ "HP1": [80,90,70,60], "int_rate": [2,1,2,3], "IND_GDP":[50,45,70,90]}, index=[ 2005,2006,2006,2007])
merge=pd.merge(df1,df2,on="HP1")
print(merge)
# Out:
#    HP1  int_rate_x  IND_GDP_x  int_rate_y  IND_GDP_y
# 0   80           2         50           2         50
# 1   90           1         45           1         45
# 2   70           2         70           2         70
# 3   60           3         90           3         90

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import style
style.use("fivethirtyeight")


df=pd.DataFrame({"Day": [1,2,3,4], "Visitors":[200,250,300,400], "Bounce_rate": [20,45,60,70]})
df.set_index("Day",inplace=True)
df.plot(kind= "bar")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-d134cdbe5ae4> in <module>
#       8 df.set_index("Day",inplace=True)
#       9 df.plot(kind= "bar")
# ---> 10 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
import pandas as pd
df1=pd.DataFrame ({ "HP1": [80,90,70,60], "int_rate": [2,1,2,3], "IND_GDP":[50,45,70,90]}, index=[ 2001,2002,2003,2004])
df1.rename(columns= {"int_rate":"Users"})
# Out:
#       HP1  Users  IND_GDP
# 2001   80      2       50
# 2002   90      1       45
# 2003   70      2       70
# 2004   60      3       90

# %%
import pandas as pd

titanic= pd.read_csv(r"C:\Users\Gopal Chavan\Downloads\titanic\test.csv")
titanic.to_html("edu.html")

# %%
import pandas as pd

car_details =({"mpg": [21,21,22.8,21.3,23,23,23,23]  ,  "cyl": [6,6,4,6,4,6,4,6], "disp": [160,160,108,108,150,108,160,160], 
     "hp": [110,110,93,96,90,110,110,110] ,"drat": [3.9,3.9,3.8,3,4,3.9,3.9,3.9]})
df =pd.DataFrame(car_details)
df
# Out:
#     mpg  cyl  disp   hp  drat
# 0  21.0    6   160  110   3.9
# 1  21.0    6   160  110   3.9
# 2  22.8    4   108   93   3.8
# 3  21.3    6   108   96   3.0
# 4  23.0    4   150   90   4.0
# 5  23.0    6   108  110   3.9
# 6  23.0    4   160  110   3.9
# 7  23.0    6   160  110   3.9

# %%
df.shape

# %%
rows ,coloums =df.shape

# %%
rows

# %%
coloums
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-919f0e2ba231> in <module>
# ----> 1 coloums
#
# NameError: name 'coloums' is not defined

# %%
df.head(2)
# Out:
#     mpg  cyl  disp   hp  drat
# 0  21.0    6   160  110   3.9
# 1  21.0    6   160  110   3.9

# %%
df.tail(4)
# Out:
#     mpg  cyl  disp   hp  drat
# 4  23.0    4   150   90   4.0
# 5  23.0    6   108  110   3.9
# 6  23.0    4   160  110   3.9
# 7  23.0    6   160  110   3.9

# %%
df[2:5]

# %%
import pandas as pd

car_details =({"mpg": [21,21,22.8,21.3,23,23,23,23]  ,  "cyl": [6,6,4,6,4,6,4,6], "disp": [160,160,108,108,150,108,160,160], 
     "hp": [110,110,93,96,90,110,110,110] ,"drat": [3.9,3.9,3.8,3,4,3.9,3.9,3.9]})
df =pd.DataFrame(car_details)
df
# Out:
#     mpg  cyl  disp   hp  drat
# 0  21.0    6   160  110   3.9
# 1  21.0    6   160  110   3.9
# 2  22.8    4   108   93   3.8
# 3  21.3    6   108   96   3.0
# 4  23.0    4   150   90   4.0
# 5  23.0    6   108  110   3.9
# 6  23.0    4   160  110   3.9
# 7  23.0    6   160  110   3.9

# %%
type(df["cyl"])
# Out:
# pandas.core.series.Series

# %%
df[["cyl","disp"]]
# Out:
#    cyl  disp
# 0    6   160
# 1    6   160
# 2    4   108
# 3    6   108
# 4    4   150
# 5    6   108
# 6    4   160
# 7    6   160

# %%
df["cyl"].mean()
# Out:
# 5.25

# %%
df["cyl"].max()

# %%
df.describe()
# Out:
#              mpg       cyl        disp          hp      drat
# count   8.000000  8.000000    8.000000    8.000000  8.000000
# mean   22.262500  5.250000  139.250000  103.625000  3.787500
# std     0.969444  1.035098   26.097345    8.943274  0.322656
# min    21.000000  4.000000  108.000000   90.000000  3.000000
# 25%    21.225000  4.000000  108.000000   95.250000  3.875000
# 50%    22.900000  6.000000  155.000000  110.000000  3.900000
# 75%    23.000000  6.000000  160.000000  110.000000  3.900000
# max    23.000000  6.000000  160.000000  110.000000  4.000000

# %%
import pandas as pd

car_details =({"mpg": [21,21,22.8,21.3,23,23,23,23]  ,  "cyl": [6,6,4,6,4,6,4,6], "disp": [160,160,108,108,150,108,160,160], 
     "hp": [110,110,93,96,90,110,110,110] ,"drat": [3.9,3.9,3.8,3,4,3.9,3.9,3.9]})
df =pd.DataFrame(car_details)
df
# Out:
#     mpg  cyl  disp   hp  drat
# 0  21.0    6   160  110   3.9
# 1  21.0    6   160  110   3.9
# 2  22.8    4   108   93   3.8
# 3  21.3    6   108   96   3.0
# 4  23.0    4   150   90   4.0
# 5  23.0    6   108  110   3.9
# 6  23.0    4   160  110   3.9
# 7  23.0    6   160  110   3.9

# %%
df[df.mpg==df.mpg.max()]
# Out:
#     mpg  cyl  disp   hp  drat
# 4  23.0    4   150   90   4.0
# 5  23.0    6   108  110   3.9
# 6  23.0    4   160  110   3.9
# 7  23.0    6   160  110   3.9

# %%
df
# Out:
#     mpg  cyl  disp   hp  drat
# 0  21.0    6   160  110   3.9
# 1  21.0    6   160  110   3.9
# 2  22.8    4   108   93   3.8
# 3  21.3    6   108   96   3.0
# 4  23.0    4   150   90   4.0
# 5  23.0    6   108  110   3.9
# 6  23.0    4   160  110   3.9
# 7  23.0    6   160  110   3.9

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)
